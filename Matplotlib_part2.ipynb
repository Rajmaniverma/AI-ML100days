# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajmaniverma/AI-ML100days/blob/main/Matplotlib_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# matplot lib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# types of plot

# %%
fig = plt.figure(figsize=(12,12));
ax1 = fig.add_axes([0.1,0.1,0.3,0.4])
