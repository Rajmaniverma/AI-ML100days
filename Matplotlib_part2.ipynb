# %%
# matplot lib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# types of plot

# %%
 x = np.linspace(1,10, 30);
 y =np.linspace(1,10,30);

plt.scatter(x,y);
plt.show()

# %%
# plt.savefig("sales.png", dpi=300);
# 1.  plt.plot()
# 2.  plt.scatter()
# 3.  plt.bar()
# 4.  plt.barh()
# 5.  plt.hist()
# 6.  plt.pie()
# 7.  plt.boxplot()
# 8.  plt.figure()
# 9.  plt.subplots()
# 10. plt.subplot()
# 11. plt.title()
# 12. plt.xlabel()
# 13. plt.ylabel()
# 14. plt.legend()
# 15. plt.grid()
# 16. plt.xlim()
# 17. plt.ylim()
# 18. plt.xticks()
# 19. plt.yticks()
# 20. plt.savefig()

# %%
plt.hist([1,1,2,3,3,4,4,4,5,5,7,9,9,7])
# Out:
# (array([2., 1., 2., 3., 0., 2., 0., 2., 0., 2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbb1aa21bd0>,
#   <matplotlib.lines.Line2D at 0x7fbb1aa21d10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbb1aa21e50>,
#   <matplotlib.lines.Line2D at 0x7fbb1aa21f90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbb1aa21a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbb1aa220d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbb1aa22210>],
#  'means': []}

# %%
# saving plots
# Out:
#   File "/tmp/ipykernel_2319/1824230471.py", line 1
#     saving plots
#            ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure();
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("sales.png")

# %%
# working with images

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("/content/Screenshot 2026-09-17 183830.png");

# %%
plt.imshow(img);
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1896.5), np.float64(904.5), np.float64(-0.5))

# %%
cropped_img = img[50:200, 200:400]
plt.imshow(img)

# %%
plt.plot(x,y,color='pink')
